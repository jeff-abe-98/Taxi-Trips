# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import json

# %matplotlib inline

# %%
regions = pd.read_csv('D:\\Capstone Data\\taxizones.csv')
manhattan = regions[regions['borough']=='Manhattan']

# %%
manhattan.head()
# Out:
#     objectid  shape_leng                                           the_geom  \
# 3          4    0.043567  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 9         24    0.047000  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 12        12    0.036661  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 13        13    0.050281  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 40        41    0.052793  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
#
#     shape_area               zone  location_id    borough
# 3     0.000112      Alphabet City            4  Manhattan
# 9     0.000061       Bloomingdale           24  Manhattan
# 12    0.000042       Battery Park           12  Manhattan
# 13    0.000149  Battery Park City           13  Manhattan
# 40    0.000143     Central Harlem           41  Manhattan

# %%
trip = pd.read_csv('D:\\Capstone Data\\Yellow Taxi\\yellowtaxi2014.csv', nrows=100)

# %%
trip.head()
# Out:
#   vendor_id          pickup_datetime         dropoff_datetime  \
# 0       CMT  2014-11-23T20:31:29.000  2014-11-23T20:31:29.000
# 1       CMT  2014-04-16T13:45:06.000  2014-04-16T14:00:21.000
# 2       CMT  2014-02-09T22:43:54.000  2014-02-09T23:06:21.000
# 3       CMT  2014-10-27T23:15:23.000  2014-10-27T23:23:54.000
# 4       VTS  2014-09-14T01:32:00.000  2014-09-14T01:44:00.000
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                3           0.00          0.000000         0.000000
# 1                1           2.40        -73.990027        40.757197
# 2                2           9.30        -73.870607        40.773682
# 3                1           2.10        -73.983611        40.769135
# 4                1           3.36        -73.949010        40.754087
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                  N           0.000000          0.000000          CSH
# ...

# %%
n = 8
zone = manhattan['zone'].iloc[n]
polygon  = eval(manhattan.the_geom.iloc[n])

# %%
coords = polygon['coordinates'][0][0]

# %%
x, y = ([coord[0] for coord in coords], [coord[1] for coord in coords])

# %%
plt.figure(figsize=(8, 8))
plt.axis('equal')
plt.title(zone)
plt.fill(x,y, zorder=1)
plt.scatter(trip.pickup_longitude[1:], trip.pickup_latitude[1:], zorder=2)
plt.show()

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-267-3c71a42b2032> in <module>
# ----> 1 from shapely.geometry import Point
#       2 from shapely.geometry.polygon import Polygon
#
# ModuleNotFoundError: No module named 'shapely'
